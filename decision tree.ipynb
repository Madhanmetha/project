# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/madhanmetha/Downloads/nyc_weather.csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.shape
# Out:
# (31, 11)

# %%
df.head(2)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df[10:20]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 10               10           NaN               0           1       NaN
# ...

# %%
df.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df[['Temperature','EST']]
# Out:
#     Temperature        EST
# 0            38   1/1/2016
# 1            36   1/2/2016
# 2            40   1/3/2016
# 3            25   1/4/2016
# 4            20   1/5/2016
# 5            33   1/6/2016
# 6            39   1/7/2016
# 7            39   1/8/2016
# 8            44   1/9/2016
# 9            50  1/10/2016
# 10           33  1/11/2016
# 11           35  1/12/2016
# 12           26  1/13/2016
# 13           30  1/14/2016
# 14           43  1/15/2016
# 15           47  1/16/2016
# 16           36  1/17/2016
# 17           25  1/18/2016
# 18           22  1/19/2016
# 19           32  1/20/2016
# 20           31  1/21/2016
# 21           26  1/22/2016
# 22           26  1/23/2016
# 23           28  1/24/2016
# 24           34  1/25/2016
# 25           43  1/26/2016
# 26           41  1/27/2016
# 27           37  1/28/2016
# 28           36  1/29/2016
# 29           34  1/30/2016
# 30           46  1/31/2016

# %%
df.Temperature.max()
# Out:
# 50

# %%
df.Temperature.min()
# Out:
# 20

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df['EST'][df['Temperature']>=35]
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 11    1/12/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df[['EST','Temperature']][df['Temperature']>=35]
# Out:
#           EST  Temperature
# 0    1/1/2016           38
# 1    1/2/2016           36
# 2    1/3/2016           40
# 6    1/7/2016           39
# 7    1/8/2016           39
# 8    1/9/2016           44
# 9   1/10/2016           50
# 11  1/12/2016           35
# 14  1/15/2016           43
# 15  1/16/2016           47
# 16  1/17/2016           36
# 25  1/26/2016           43
# 26  1/27/2016           41
# 27  1/28/2016           37
# 28  1/29/2016           36
# 30  1/31/2016           46

# %%
df[['EST','Temperature']][df['Temperature']==df.Temperature.max()]
# Out:
#          EST  Temperature
# 9  1/10/2016           50

# %%
weather={
    "days":["1-1-2024","2-1-2024","3-1-2024"],
    "temp":[33,34,35],
    "event":["rain","snow","sunny"]
}
a=pd.DataFrame(weather)
a
# Out:
#        days  temp  event
# 0  1-1-2024    33   rain
# 1  2-1-2024    34   snow
# 2  3-1-2024    35  sunny

# %%
lst={
    ("1-1-2024",33,"rainy"),
    ("2-1-2024",34,"snowy"),
    ("3-1-2024",35,"sunny"),
}
b=pd.DataFrame(lst)
b
# Out:
#           0   1      2
# 0  3-1-2024  35  sunny
# 1  1-1-2024  33  rainy
# 2  2-1-2024  34  snowy

# %%
lst={
    ("1-1-2024",33,"rainy"),
    ("2-1-2024",34,"snowy"),
    ("3-1-2024",35,"sunny"),
}
b=pd.DataFrame(lst,columns=("EST","TEMP","EVENT"))
b
# Out:
#         EST  TEMP  EVENT
# 0  3-1-2024    35  sunny
# 1  1-1-2024    33  rainy
# 2  2-1-2024    34  snowy

# %%
app=[
    {"days":"1-1-2024","temp":33,"event":"rainy"},
    {"days":"2-1-2024","event":"snowy"},
    {"days":"3-1-2024","temp":35,"event":"sunny"}
]
c=pd.DataFrame(app)
c
# Out:
#        days  temp  event
# 0  1-1-2024  33.0  rainy
# 1  2-1-2024   NaN  snowy
# 2  3-1-2024  35.0  sunny

# %%
import csv
with open(r"/Users/madhanmetha/Downloads/nyc_weather.csv","r") as files:
    reader=csv.reader(files)

    for i in reader:
        print(i)
# Out:
# ['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn', 'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover', 'Events', 'WindDirDegrees']
# ['1/1/2016', '38', '23', '52', '30.03', '10', '8', '0', '5', '', '281']
# ['1/2/2016', '36', '18', '46', '30.02', '10', '7', '0', '3', '', '275']
# ['1/3/2016', '40', '21', '47', '29.86', '10', '8', '0', '1', '', '277']
# ['1/4/2016', '25', '9', '44', '30.05', '10', '9', '0', '3', '', '345']
# ['1/5/2016', '20', '-3', '41', '30.57', '10', '5', '0', '0', '', '333']
# ['1/6/2016', '33', '4', '35', '30.5', '10', '4', '0', '0', '', '259']
# ['1/7/2016', '39', '11', '33', '30.28', '10', '2', '0', '3', '', '293']
# ['1/8/2016', '39', '29', '64', '30.2', '10', '4', '0', '8', '', '79']
# ['1/9/2016', '44', '38', '77', '30.16', '9', '8', 'T', '8', 'Rain', '76']
# ['1/10/2016', '50', '46', '71', '29.59', '4', '', '1.8', '7', 'Rain', '109']
# ['1/11/2016', '33', '8', '37', '29.92', '10', '', '0', '1', '', '289']
# ...

# %%
app=[
    {"days":"1-1-2024","temp":33,"event":"rainy"},
    {"days":"2-1-2024","event":"snowy"},
    {"days":"3-1-2024","temp":35,"event":"sunny"}
]
c=pd.DataFrame(app)
c
# Out:
#        days  temp  event
# 0  1-1-2024  33.0  rainy
# 1  2-1-2024   NaN  snowy
# 2  3-1-2024  35.0  sunny

# %%
c.to_csv(r"/Users/madhanmetha/Desktop/jupiter notebook /abc.csv")

# %%
# new new new new new new nwe

# %%
df=pd.read_csv("/Users/madhanmetha/Downloads/music.csv")
df
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
x=df[["age","gender"]]
x
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
x=df[["age","gender"]]
y=df["genre"]
y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)
x_train
# Out:
#     age  gender
# 1    23       1
# 0    20       1
# 12   26       0
# 15   31       0
# 10   21       0
# 3    26       1
# 4    29       1
# 17   35       0
# 5    30       1
# 2    25       1
# 9    20       0
# 11   25       0
# 8    37       1
# 13   27       0

# %%
from sklearn.tree import DecisionTreeClassifier,export_graphviz 
import joblib

# %%
model=DecisionTreeClassifier()

# %%
# to run faster without training all data
# joblib.dump(model,"/Users/madhanmetha/Desktop/jupiter notebook /trained.joblib")

# %%
model.fit(x,y)
# once dumped no need to be used
joblib.load("/Users/madhanmetha/Desktop/jupiter notebook /trained.joblib")
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[22,1]])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop'], dtype=object)

# %%
x_test.shape
# Out:
# (4, 2)

# %%
x_train.shape
# Out:
# (14, 2)

# %%
model.predict(x_test)
# Out:
# array(['Classical', 'Classical', 'Acoustic', 'Classical'], dtype=object)

# %%
model.predict(x_train)
# Out:
# array(['HipHop', 'HipHop', 'Acoustic', 'Classical', 'Dance', 'Jazz',
#        'Jazz', 'Classical', 'Jazz', 'HipHop', 'Dance', 'Dance',
#        'Classical', 'Acoustic'], dtype=object)

# %%
x_train
# Out:
#     age  gender
# 1    23       1
# 0    20       1
# 12   26       0
# 15   31       0
# 10   21       0
# 3    26       1
# 4    29       1
# 17   35       0
# 5    30       1
# 2    25       1
# 9    20       0
# 11   25       0
# 8    37       1
# 13   27       0

# %%
y_test
# Out:
# 7     Classical
# 16    Classical
# 14     Acoustic
# 6     Classical
# Name: genre, dtype: object

# %%
prediction=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction)
# Out:
# 1.0

# %%
export_graphviz(model,out_file="/Users/madhanmetha/Desktop/jupiter notebook /trained.dot",
               feature_names=['age','gender'],
               class_names=sorted(y.unique()),
               label="all",rounded=True,filled=True)
