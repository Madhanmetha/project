# %%
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.linear_model import LogisticRegression

# %%
column_names = [f'data{i+1}' for i in range(61)]

# %%
df=pd.read_csv("/Users/madhanmetha/Downloads/sonar.csv",names=column_names)
df.rename(columns={'data61': 'ANS'}, inplace=True)
df
# Out:
#       data1   data2   data3   data4   data5   data6   data7   data8   data9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
x=df.loc[:, 'data1':'data60']
x
# Out:
#       data1   data2   data3   data4   data5   data6   data7   data8   data9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
y=df["ANS"]
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: ANS, Length: 208, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1)
x_train
# Out:
#       data1   data2   data3   data4   data5   data6   data7   data8   data9  \
# 194  0.0392  0.0108  0.0267  0.0257  0.0410  0.0491  0.1053  0.1690  0.2105
# 65   0.0176  0.0172  0.0501  0.0285  0.0262  0.0351  0.0362  0.0535  0.0258
# 175  0.0294  0.0123  0.0117  0.0113  0.0497  0.0998  0.1326  0.1117  0.2984
# 143  0.0516  0.0944  0.0622  0.0415  0.0995  0.2431  0.1777  0.2018  0.2611
# 96   0.0181  0.0146  0.0026  0.0141  0.0421  0.0473  0.0361  0.0741  0.1398
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 146  0.1021  0.0830  0.0577  0.0627  0.0635  0.1328  0.0988  0.1787  0.1199
# 17   0.0192  0.0607  0.0378  0.0774  0.1388  0.0809  0.0568  0.0219  0.1037
# 182  0.0095  0.0308  0.0539  0.0411  0.0613  0.1039  0.1016  0.1394  0.2592
# 49   0.0119  0.0582  0.0623  0.0600  0.1397  0.1883  0.1422  0.1447  0.0487
# 31   0.0084  0.0153  0.0291  0.0432  0.0951  0.0752  0.0414  0.0259  0.0692
#
# ...

# %%
x_test
# Out:
#       data1   data2   data3   data4   data5   data6   data7   data8   data9  \
# 171  0.0179  0.0136  0.0408  0.0633  0.0596  0.0808  0.2090  0.3465  0.5276
# 84   0.0378  0.0318  0.0423  0.0350  0.1787  0.1635  0.0887  0.0817  0.1779
# 113  0.0283  0.0599  0.0656  0.0229  0.0839  0.1673  0.1154  0.1098  0.1370
# 122  0.0249  0.0119  0.0277  0.0760  0.1218  0.1538  0.1192  0.1229  0.2119
# 159  0.0235  0.0220  0.0167  0.0516  0.0746  0.1121  0.1258  0.1717  0.3074
# 167  0.0137  0.0297  0.0116  0.0082  0.0241  0.0253  0.0279  0.0130  0.0489
# 166  0.0411  0.0277  0.0604  0.0525  0.0489  0.0385  0.0611  0.1117  0.1237
# 48   0.0190  0.0038  0.0642  0.0452  0.0333  0.0690  0.0901  0.1454  0.0740
# 137  0.0430  0.0902  0.0833  0.0813  0.0165  0.0277  0.0569  0.2057  0.3887
# 123  0.0270  0.0163  0.0341  0.0247  0.0822  0.1256  0.1323  0.1584  0.2017
# 51   0.0131  0.0068  0.0308  0.0311  0.0085  0.0767  0.0771  0.0640  0.0726
# ...

# %%
x_train
# Out:
#       data1   data2   data3   data4   data5   data6   data7   data8   data9  \
# 194  0.0392  0.0108  0.0267  0.0257  0.0410  0.0491  0.1053  0.1690  0.2105
# 65   0.0176  0.0172  0.0501  0.0285  0.0262  0.0351  0.0362  0.0535  0.0258
# 175  0.0294  0.0123  0.0117  0.0113  0.0497  0.0998  0.1326  0.1117  0.2984
# 143  0.0516  0.0944  0.0622  0.0415  0.0995  0.2431  0.1777  0.2018  0.2611
# 96   0.0181  0.0146  0.0026  0.0141  0.0421  0.0473  0.0361  0.0741  0.1398
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 146  0.1021  0.0830  0.0577  0.0627  0.0635  0.1328  0.0988  0.1787  0.1199
# 17   0.0192  0.0607  0.0378  0.0774  0.1388  0.0809  0.0568  0.0219  0.1037
# 182  0.0095  0.0308  0.0539  0.0411  0.0613  0.1039  0.1016  0.1394  0.2592
# 49   0.0119  0.0582  0.0623  0.0600  0.1397  0.1883  0.1422  0.1447  0.0487
# 31   0.0084  0.0153  0.0291  0.0432  0.0951  0.0752  0.0414  0.0259  0.0692
#
# ...

# %%
y_test
# Out:
# 171    M
# 84     R
# 113    M
# 122    M
# 159    M
# 167    M
# 166    M
# 48     R
# 137    M
# 123    M
# 51     R
# 16     R
# 126    M
# 148    M
# 38     R
# 89     R
# 138    M
# 172    M
# 53     R
# 206    M
# 132    M
# Name: ANS, dtype: object

# %%
y_train
# Out:
# 194    M
# 65     R
# 175    M
# 143    M
# 96     R
#       ..
# 146    M
# 17     R
# 182    M
# 49     R
# 31     R
# Name: ANS, Length: 187, dtype: object

# %%
# from sklearn.tree import DecisionTreeClassifier

# %%
model=LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
model.predict(x_train)
# Out:
# array(['M', 'R', 'M', 'M', 'R', 'M', 'R', 'R', 'R', 'R', 'M', 'R', 'M',
#        'R', 'M', 'M', 'R', 'M', 'R', 'R', 'R', 'R', 'R', 'R', 'M', 'M',
#        'M', 'M', 'R', 'M', 'M', 'M', 'R', 'M', 'M', 'R', 'M', 'R', 'M',
#        'M', 'M', 'M', 'M', 'R', 'M', 'R', 'M', 'M', 'M', 'R', 'M', 'M',
#        'R', 'M', 'M', 'M', 'M', 'R', 'M', 'M', 'M', 'R', 'R', 'R', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'R', 'M', 'M', 'M', 'R', 'R',
#        'R', 'M', 'M', 'M', 'M', 'M', 'R', 'R', 'M', 'R', 'R', 'M', 'R',
#        'M', 'R', 'M', 'M', 'M', 'R', 'M', 'M', 'R', 'R', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'R', 'M', 'R', 'R', 'M', 'M', 'R', 'R', 'M',
#        'M', 'R', 'M', 'M', 'M', 'M', 'M', 'R', 'M', 'R', 'M', 'R', 'M',
#        'R', 'R', 'R', 'M', 'R', 'M', 'R', 'M', 'M', 'M', 'R', 'R', 'M',
#        'M', 'R', 'R', 'M', 'M', 'R', 'R', 'M', 'R', 'M', 'R', 'M', 'M',
#        'M', 'M', 'R', 'R', 'M', 'R', 'R', 'R', 'R', 'R', 'M', 'R', 'M',
# ...

# %%
model.predict(x_test)
# Out:
# array(['M', 'M', 'M', 'M', 'R', 'M', 'M', 'R', 'M', 'M', 'R', 'R', 'M',
#        'M', 'R', 'R', 'M', 'M', 'R', 'M', 'M'], dtype=object)

# %%
prediction=model.predict(x_test)
# prediction1=model.predict(x_train)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction)
# Out:
# 0.9047619047619048
